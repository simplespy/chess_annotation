# %%
import pandas as pd

# %%
df = pd.read_json("data/step2_qwen3_scored.jsonl", lines=True)

# %%
high_quality = df[df["slm_score"] >= 5]
high_quality
# Out:
#                         id  game_idx  \
# 16053    game3481_move22_w      3481
# 19748     game4428_move3_w      4428
# 66417    game15107_move8_w     15107
# 87383   game19932_move17_b     19932
# 98001    game22248_move1_w     22248
# 117077  game26541_move22_b     26541
# 134743  game30577_move28_b     30577
# 139152  game31650_move16_b     31650
# 142685  game32523_move23_w     32523
# 160451  game36517_move15_b     36517
# 187959  game42822_move20_b     42822
# 207951  game47411_move41_w     47411
# 210715   game48046_move7_b     48046
# 217851  game49819_move15_w     49819
# 220419   game50398_move6_b     50398
# 229783  game52401_move10_b     52401
# 246086   game56045_move1_w     56045
# 252391   game57654_move7_b     57654
# 291770  game66706_move37_w     66706
# 302253   game69200_move1_w     69200
# 313714  game72206_move15_b     72206
# 355192  game82114_move10_b     82114
#
#                                                       fen   move move_uci  \
# ...

# %%
len(high_quality)
# Out:
# 22
